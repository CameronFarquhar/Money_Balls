# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st
from datetime import date
from functools import reduce
import json
import ctypes
import seaborn as sns
import datetime

# %%
df = pd.read_csv('../Data/SUB-IP-EST2019-ANNRNK-1.csv')
# df['City Name'] = df['Geographic Area'].str.split(', ').apply(lambda x: x[0])
df.dropna()
df['2018'] = df['2018'].astype('int64')
# df['Geographic Area'] = df['Geographic Area'].astype('str')
df.dtypes
# Out:
# Geographic Area    object
# 2018                int64
# dtype: object

# %%
df['City Name'] = df['Geographic Area'].str.split(', ').apply(lambda x: x[0])
df['State Name'] = df['Geographic Area'].str.split(', ').apply(lambda x: x[-1])
df['City Name'] = df['City Name'].str.rstrip('city')
df.rename(columns = {"2018":"Population"}, inplace = True)
df.drop(columns = ["Geographic Area"], inplace = True)
df['City Name'] = df['City Name'].astype(str)
df.reset_index()
# Out:
#      index  Population       City Name     State Name
# 0        0     8390081       New York        New York
# 1        1     3977596    Los Angeles      California
# 2        2     2701423        Chicago        Illinois
# 3        3     2318573        Houston           Texas
# 4        4     1654675        Phoenix         Arizona
# ..     ...         ...             ...            ...
# 783    783       50012       Lakewood            Ohio
# 784    784       49354           Troy        New York
# 785    785       48310        Saginaw        Michigan
# 786    786       48012  Niagara Falls        New York
# 787    787       47172     Charleston   West Virginia
#
# [788 rows x 4 columns]

# %%
df
# Out:
#      Population       City Name     State Name
# 0       8390081       New York        New York
# 1       3977596    Los Angeles      California
# 2       2701423        Chicago        Illinois
# 3       2318573        Houston           Texas
# 4       1654675        Phoenix         Arizona
# ..          ...             ...            ...
# 783       50012       Lakewood            Ohio
# 784       49354           Troy        New York
# 785       48310        Saginaw        Michigan
# 786       48012  Niagara Falls        New York
# 787       47172     Charleston   West Virginia
#
# [788 rows x 3 columns]

# %%
# code coppied from https://gist.github.com/rogerallen/1583593
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}

# %%
df['State Name'] = df['State Name'].map(us_state_abbrev).fillna(df['State Name'])
df
# Out:
#      Population       City Name State Name
# 0       8390081       New York          NY
# 1       3977596    Los Angeles          CA
# 2       2701423        Chicago          IL
# 3       2318573        Houston          TX
# 4       1654675        Phoenix          AZ
# ..          ...             ...        ...
# 783       50012       Lakewood          OH
# 784       49354           Troy          NY
# 785       48310        Saginaw          MI
# 786       48012  Niagara Falls          NY
# 787       47172     Charleston          WV
#
# [788 rows x 3 columns]

# %%
us_state_abbrev = {state: abbrev for abbrev, state in us_state_abbrev.items()}
df['State'] = df['State Name'].map(us_state_abbrev)
df
# Out:
#      Population       City Name State Name          State
# 0       8390081       New York          NY       New York
# 1       3977596    Los Angeles          CA     California
# 2       2701423        Chicago          IL       Illinois
# 3       2318573        Houston          TX          Texas
# 4       1654675        Phoenix          AZ        Arizona
# ..          ...             ...        ...            ...
# 783       50012       Lakewood          OH           Ohio
# 784       49354           Troy          NY       New York
# 785       48310        Saginaw          MI       Michigan
# 786       48012  Niagara Falls          NY       New York
# 787       47172     Charleston          WV  West Virginia
#
# [788 rows x 4 columns]

# %%
df.drop(columns = ['State'], inplace = True)
df.rename(columns = {"City Name":"City"}, inplace = True)
pop_df = df

# %%
df.loc[df['City'] == 'Indianapolis']
# Out:
# Empty DataFrame
# Columns: [Population, City, State Name]
# Index: []

# %%
nba_df = pd.read_csv('../Data/Forbes-NHL-Revenue-2018.csv')
nba_df
# Out:
#                     ﻿Team           City State/Province    Revenue
# 0        New York Rangers  New York City             NY  253000000
# 1     Toronto Maple Leafs        Toronto             ON  232000000
# 2      Montreal Canadiens       Montreal             QC  239000000
# 3      Chicago Blackhawks        Chicago             IL  201000000
# 4           Boston Bruins         Boston             MA  191000000
# 5       Los Angeles Kings    Los Angeles             CA  193000000
# 6     Philadelphia Flyers   Philadelphia             PA  186000000
# 7       Detroit Red Wings        Detroit             MI  171000000
# 8       Vancouver Canucks      Vancouver             BC  168000000
# 9     Washington Capitals     Washington             DC  194000000
# 10    Pittsburgh Penguins     Pittsburgh             PA  185000000
# 11   Vegas Golden Knights      Las Vegas             NV  180000000
# 12        Edmonton Oilers       Edmonton             AB  145000000
# 13           Dallas Stars         Dallas             TX  144000000
# 14        San Jose Sharks       San Jose             CA  148000000
# 15         Minnesota Wild     Saint Paul             MN  142000000
# 16         St Louis Blues    Saint Louis             MO  148000000
# 17          Anaheim Ducks        Anaheim             CA  134000000
# 18      New Jersey Devils         Newark             NJ  166000000
# 19         Calgary Flames        Calgary             AB  132000000
# 20    Tampa Bay Lightning      Tampa Bay             FL  146000000
# 21     New York Islanders      Uniondale             NY  107000000
# 22        Ottawa Senators         Ottowa             ON  124000000
# 23     Colorado Avalanche         Denver             CO  119000000
# 24    Nashville Predators      Nashville             TN  132000000
# 25    Carolina Hurricanes        Raleigh             NC  109000000
# 26          Winnipeg Jets       Winnipeg             MB  135000000
# 27         Buffalo Sabres        Buffalo             NY  128000000
# 28  Columbus Blue Jackets       Columbus             OH  111000000
# 29       Florida Panthers          Miami             FL   99000000
# 30        Arizona Coyotes       Glendale             AZ   96000000

# %%
pop_df['City'] = pop_df['City'].str.strip()
nba_df['City'] = nba_df['City'].str.strip()
nba_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ﻿Team           31 non-null     object
#  1   City            31 non-null     object
#  2   State/Province  31 non-null     object
#  3   Revenue         31 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 1.1+ KB

# %%
merged_nba_df = pd.merge(nba_df, pop_df, how='inner', on = ['City'])

# %% [markdown]
# merged_nba_df

# %%
merged_nba_df
# Out:
#                     ﻿Team          City State/Province    Revenue  Population  \
# 0      Chicago Blackhawks       Chicago             IL  201000000     2701423
# 1           Boston Bruins        Boston             MA  191000000      691147
# 2       Los Angeles Kings   Los Angeles             CA  193000000     3977596
# 3     Philadelphia Flyers  Philadelphia             PA  186000000     1583592
# 4       Detroit Red Wings       Detroit             MI  171000000      672977
# 5       Vancouver Canucks     Vancouver             BC  168000000      182887
# 6     Washington Capitals    Washington             DC  194000000      701547
# 7     Pittsburgh Penguins    Pittsburgh             PA  185000000      300570
# 8    Vegas Golden Knights     Las Vegas             NV  180000000      643228
# 9            Dallas Stars        Dallas             TX  144000000     1341802
# 10        San Jose Sharks      San Jose             CA  148000000     1028020
# 11          Anaheim Ducks       Anaheim             CA  134000000      350698
# 12      New Jersey Devils        Newark             NJ  166000000      281752
# 13      New Jersey Devils        Newark             NJ  166000000       50001
# 14     Colorado Avalanche        Denver             CO  119000000      716265
# 15    Carolina Hurricanes       Raleigh             NC  109000000      469314
# 16         Buffalo Sabres       Buffalo             NY  128000000      255781
# 17  Columbus Blue Jackets      Columbus             OH  111000000      890869
# 18  Columbus Blue Jackets      Columbus             OH  111000000      194169
# 19       Florida Panthers         Miami             FL   99000000      462819
# 20        Arizona Coyotes      Glendale             AZ   96000000      249955
# 21        Arizona Coyotes      Glendale             AZ   96000000      200688
#
#    State Name
# 0          IL
# 1          MA
# 2          CA
# 3          PA
# 4          MI
# 5          WA
# 6          DC
# 7          PA
# 8          NV
# 9          TX
# 10         CA
# 11         CA
# 12         NJ
# 13         OH
# 14         CO
# 15         NC
# 16         NY
# 17         OH
# 18         GA
# 19         FL
# 20         AZ
# 21         CA

# %%
# merged_nba_df = merged_nba_df.loc[merged_nba_df['State Name'] != 'ME']
# merged_nba_df.reset_index()
# merged_nba_df
# cleaned_merged_nba_df = merged_nba_df.drop(merged_nba_df.index[14])
cleaned_merged_nba_df.reset_index()
# merged_nba_df.drop(columns = ["index"], inplace = True)
cleaned_merged_nba_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-8d2f5564d456> in <module>
#       3 # merged_nba_df
#       4 # cleaned_merged_nba_df = merged_nba_df.drop(merged_nba_df.index[14])
# ----> 5 cleaned_merged_nba_df.reset_index()
#       6 # merged_nba_df.drop(columns = ["index"], inplace = True)
#       7 cleaned_merged_nba_df
#
# NameError: name 'cleaned_merged_nba_df' is not defined

# %%
# df.to_csv("pop_cities.csv", encoding="utf-8", index=False)

# %%
income_df = pd.read_csv('../Data/lapi1120msa-1.csv')
income_df.dropna()
income_df['Income'] = income_df['2018.00'].astype('int64')
income_df = income_df.dropna(how='any')
income_df.drop(columns = ['2018.00'], inplace = True)
income_df.reset_index()
income_df
# Out:
#         Metropolitan Statistical Areas  Income
# 0                          Abilene, TX   43585
# 1                            Akron, OH   49556
# 2                           Albany, GA   38034
# 3                   Albany-Lebanon, OR   43327
# 4          Albany-Schenectady-Troy, NY   58443
# ..                                 ...     ...
# 379                         Yakima, WA   43905
# 380                   York-Hanover, PA   49888
# 381  Youngstown-Warren-Boardman, OH-PA   42255
# 382                      Yuba City, CA   43662
# 383                           Yuma, AZ   35012
#
# [384 rows x 2 columns]

# %%
income_df['City Name'] = income_df['Metropolitan Statistical Areas'].str.split(', ').apply(lambda x: x[0])
income_df['State Name'] = income_df['Metropolitan Statistical Areas'].str.split(', ').apply(lambda x: x[-1])
income_df.drop(columns = ['Metropolitan Statistical Areas'], inplace = True)
income_df.reset_index()
# Out:
#      index  Income                   City Name State Name
# 0        0   43585                     Abilene         TX
# 1        1   49556                       Akron         OH
# 2        2   38034                      Albany         GA
# 3        3   43327              Albany-Lebanon         OR
# 4        4   58443     Albany-Schenectady-Troy         NY
# ..     ...     ...                         ...        ...
# 379    379   43905                      Yakima         WA
# 380    380   49888                York-Hanover         PA
# 381    381   42255  Youngstown-Warren-Boardman      OH-PA
# 382    382   43662                   Yuba City         CA
# 383    383   35012                        Yuma         AZ
#
# [384 rows x 4 columns]

# %%
# code found at https://riptutorial.com/pandas/example/25462/split--reshape--csv-strings-in-columns-into-multiple-rows--having-one-element-per-row

reshaped_city = \
(income_df.set_index(income_df.columns.drop('City Name',1).tolist())
   ['City Name'].str.split('-', expand=True)
   .stack()
   .reset_index()
   .rename(columns={0:'City Name'})
   .loc[:, income_df.columns]
)

reshaped_city
# Out:
#      Income   City Name State Name
# 0     43585     Abilene         TX
# 1     49556       Akron         OH
# 2     38034      Albany         GA
# 3     43327      Albany         OR
# 4     43327     Lebanon         OR
# ..      ...         ...        ...
# 579   42255  Youngstown      OH-PA
# 580   42255      Warren      OH-PA
# 581   42255    Boardman      OH-PA
# 582   43662   Yuba City         CA
# 583   35012        Yuma         AZ
#
# [584 rows x 3 columns]

# %%
reshaped_state = \
(reshaped_city.set_index(reshaped_city.columns.drop('State Name',1).tolist())
   ['State Name'].str.split('-', expand=True)
   .stack()
   .reset_index()
   .rename(columns={0:'State Name'})
   .loc[:, reshaped_city.columns]
)

reshaped_state
# Out:
#      Income  City Name State Name
# 0     43585    Abilene         TX
# 1     49556      Akron         OH
# 2     38034     Albany         GA
# 3     43327     Albany         OR
# 4     43327    Lebanon         OR
# ..      ...        ...        ...
# 683   42255     Warren         PA
# 684   42255   Boardman         OH
# 685   42255   Boardman         PA
# 686   43662  Yuba City         CA
# 687   35012       Yuma         AZ
#
# [688 rows x 3 columns]

# %%
city_income_df = reshaped_state

# %%
city_income_df.rename(columns = {"City Name":"City"}, inplace = True)
city_income_df
# Out:
#      Income       City State Name
# 0     43585    Abilene         TX
# 1     49556      Akron         OH
# 2     38034     Albany         GA
# 3     43327     Albany         OR
# 4     43327    Lebanon         OR
# ..      ...        ...        ...
# 683   42255     Warren         PA
# 684   42255   Boardman         OH
# 685   42255   Boardman         PA
# 686   43662  Yuba City         CA
# 687   35012       Yuma         AZ
#
# [688 rows x 3 columns]

# %%
merged_nba_df['City'] = merged_nba_df['City'].str.strip()
city_income_df['City'] = city_income_df['City'].str.strip()
pop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 788 entries, 0 to 787
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Population  788 non-null    int64
#  1   City        788 non-null    object
#  2   State Name  788 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 18.6+ KB

# %%
merged_in_pop_nba_df = pd.merge(merged_nba_df, city_income_df, how='inner', on = ['City'])
merged_in_pop_nba_df
# Out:
#                     ﻿Team          City State/Province    Revenue  Population  \
# 0      Chicago Blackhawks       Chicago             IL  201000000     2701423
# 1      Chicago Blackhawks       Chicago             IL  201000000     2701423
# 2      Chicago Blackhawks       Chicago             IL  201000000     2701423
# 3           Boston Bruins        Boston             MA  191000000      691147
# 4           Boston Bruins        Boston             MA  191000000      691147
# 5       Los Angeles Kings   Los Angeles             CA  193000000     3977596
# 6     Philadelphia Flyers  Philadelphia             PA  186000000     1583592
# 7     Philadelphia Flyers  Philadelphia             PA  186000000     1583592
# 8     Philadelphia Flyers  Philadelphia             PA  186000000     1583592
# 9     Philadelphia Flyers  Philadelphia             PA  186000000     1583592
# 10      Detroit Red Wings       Detroit             MI  171000000      672977
# 11      Vancouver Canucks     Vancouver             BC  168000000      182887
# 12      Vancouver Canucks     Vancouver             BC  168000000      182887
# 13    Washington Capitals    Washington             DC  194000000      701547
# 14    Washington Capitals    Washington             DC  194000000      701547
# 15    Washington Capitals    Washington             DC  194000000      701547
# 16    Washington Capitals    Washington             DC  194000000      701547
# 17    Pittsburgh Penguins    Pittsburgh             PA  185000000      300570
# 18   Vegas Golden Knights     Las Vegas             NV  180000000      643228
# 19           Dallas Stars        Dallas             TX  144000000     1341802
# 20        San Jose Sharks      San Jose             CA  148000000     1028020
# 21          Anaheim Ducks       Anaheim             CA  134000000      350698
# 22      New Jersey Devils        Newark             NJ  166000000      281752
# 23      New Jersey Devils        Newark             NJ  166000000      281752
# 24      New Jersey Devils        Newark             NJ  166000000      281752
# 25      New Jersey Devils        Newark             NJ  166000000       50001
# 26      New Jersey Devils        Newark             NJ  166000000       50001
# 27      New Jersey Devils        Newark             NJ  166000000       50001
# 28     Colorado Avalanche        Denver             CO  119000000      716265
# 29    Carolina Hurricanes       Raleigh             NC  109000000      469314
# 30         Buffalo Sabres       Buffalo             NY  128000000      255781
# 31  Columbus Blue Jackets      Columbus             OH  111000000      890869
# 32  Columbus Blue Jackets      Columbus             OH  111000000      890869
# 33  Columbus Blue Jackets      Columbus             OH  111000000      890869
# 34  Columbus Blue Jackets      Columbus             OH  111000000      890869
# 35  Columbus Blue Jackets      Columbus             OH  111000000      194169
# 36  Columbus Blue Jackets      Columbus             OH  111000000      194169
# 37  Columbus Blue Jackets      Columbus             OH  111000000      194169
# 38  Columbus Blue Jackets      Columbus             OH  111000000      194169
# 39       Florida Panthers         Miami             FL   99000000      462819
#
#    State Name_x  Income State Name_y
# 0            IL   61642           IL
# 1            IL   61642           IN
# 2            IL   61642           WI
# 3            MA   78923           MA
# 4            MA   78923           NH
# 5            CA   63886           CA
# 6            PA   64228           PA
# 7            PA   64228           NJ
# 8            PA   64228           DE
# 9            PA   64228           MD
# 10           MI   52572           MI
# 11           WA   57903           OR
# 12           WA   57903           WA
# 13           DC   72340           DC
# 14           DC   72340           VA
# 15           DC   72340           MD
# 16           DC   72340           WV
# 17           PA   58206           PA
# 18           NV   47759           NV
# 19           TX   56864           TX
# 20           CA  108565           CA
# 21           CA   63886           CA
# 22           NJ   76565           NY
# 23           NJ   76565           NJ
# 24           NJ   76565           PA
# 25           OH   76565           NY
# 26           OH   76565           NJ
# 27           OH   76565           PA
# 28           CO   64690           CO
# 29           NC   56207           NC
# 30           NY   50261           NY
# 31           OH   40980           GA
# 32           OH   40980           AL
# 33           OH   51234           IN
# 34           OH   51114           OH
# 35           GA   40980           GA
# 36           GA   40980           AL
# 37           GA   51234           IN
# 38           GA   51114           OH
# 39           FL   59151           FL

# %%
merged_in_pop_nba_df = merged_in_pop_nba_df.drop_duplicates(subset=['Team'])
merged_in_pop_nba_df.reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-80018fa4ba17> in <module>
# ----> 1 merged_in_pop_nba_df = merged_in_pop_nba_df.drop_duplicates(subset=['Team'])
#       2 merged_in_pop_nba_df.reset_index()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in drop_duplicates(self, subset, keep, inplace, ignore_index)
#    4809
#    4810         inplace = validate_bool_kwarg(inplace, "inplace")
# -> 4811         duplicated = self.duplicated(subset, keep=keep)
#    4812
#    4813         if inplace:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in duplicated(self, subset, keep)
#    4883         diff = Index(subset).difference(self.columns)
#    4884         if not diff.empty:
# -> 4885             raise KeyError(diff)
#    4886
#    4887         vals = (col.values for name, col in self.items() if name in subset)
#
# KeyError: Index(['Team'], dtype='object')

# %%
merged_in_pop_nba_df.sort_values("Team")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-2d915f2437b4> in <module>
# ----> 1 merged_in_pop_nba_df.sort_values("Team")
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index)
#    4925
#    4926             by = by[0]
# -> 4927             k = self._get_label_or_level_values(by, axis=axis)
#    4928
#    4929             if isinstance(ascending, (tuple, list)):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1690             values = self.axes[axis].get_level_values(key)._values
#    1691         else:
# -> 1692             raise KeyError(key)
#    1693
#    1694         # Check for duplicates
#
# KeyError: 'Team'

# %%
merged_in_pop_nba_df.rename(columns = {"State/Province":"State"}, inplace = True)
merged_in_pop_nba_df.drop(columns = ["State Name_x"], inplace = True)
merged_in_pop_nba_df.drop(columns = ["State Name_y"], inplace = True)
merged_in_pop_nba_df
# Out:
#                     ﻿Team          City State    Revenue  Population  Income
# 0      Chicago Blackhawks       Chicago    IL  201000000     2701423   61642
# 1      Chicago Blackhawks       Chicago    IL  201000000     2701423   61642
# 2      Chicago Blackhawks       Chicago    IL  201000000     2701423   61642
# 3           Boston Bruins        Boston    MA  191000000      691147   78923
# 4           Boston Bruins        Boston    MA  191000000      691147   78923
# 5       Los Angeles Kings   Los Angeles    CA  193000000     3977596   63886
# 6     Philadelphia Flyers  Philadelphia    PA  186000000     1583592   64228
# 7     Philadelphia Flyers  Philadelphia    PA  186000000     1583592   64228
# 8     Philadelphia Flyers  Philadelphia    PA  186000000     1583592   64228
# 9     Philadelphia Flyers  Philadelphia    PA  186000000     1583592   64228
# 10      Detroit Red Wings       Detroit    MI  171000000      672977   52572
# 11      Vancouver Canucks     Vancouver    BC  168000000      182887   57903
# 12      Vancouver Canucks     Vancouver    BC  168000000      182887   57903
# 13    Washington Capitals    Washington    DC  194000000      701547   72340
# 14    Washington Capitals    Washington    DC  194000000      701547   72340
# 15    Washington Capitals    Washington    DC  194000000      701547   72340
# 16    Washington Capitals    Washington    DC  194000000      701547   72340
# 17    Pittsburgh Penguins    Pittsburgh    PA  185000000      300570   58206
# 18   Vegas Golden Knights     Las Vegas    NV  180000000      643228   47759
# 19           Dallas Stars        Dallas    TX  144000000     1341802   56864
# 20        San Jose Sharks      San Jose    CA  148000000     1028020  108565
# 21          Anaheim Ducks       Anaheim    CA  134000000      350698   63886
# 22      New Jersey Devils        Newark    NJ  166000000      281752   76565
# 23      New Jersey Devils        Newark    NJ  166000000      281752   76565
# 24      New Jersey Devils        Newark    NJ  166000000      281752   76565
# 25      New Jersey Devils        Newark    NJ  166000000       50001   76565
# 26      New Jersey Devils        Newark    NJ  166000000       50001   76565
# 27      New Jersey Devils        Newark    NJ  166000000       50001   76565
# 28     Colorado Avalanche        Denver    CO  119000000      716265   64690
# 29    Carolina Hurricanes       Raleigh    NC  109000000      469314   56207
# 30         Buffalo Sabres       Buffalo    NY  128000000      255781   50261
# 31  Columbus Blue Jackets      Columbus    OH  111000000      890869   40980
# 32  Columbus Blue Jackets      Columbus    OH  111000000      890869   40980
# 33  Columbus Blue Jackets      Columbus    OH  111000000      890869   51234
# 34  Columbus Blue Jackets      Columbus    OH  111000000      890869   51114
# 35  Columbus Blue Jackets      Columbus    OH  111000000      194169   40980
# 36  Columbus Blue Jackets      Columbus    OH  111000000      194169   40980
# 37  Columbus Blue Jackets      Columbus    OH  111000000      194169   51234
# 38  Columbus Blue Jackets      Columbus    OH  111000000      194169   51114
# 39       Florida Panthers         Miami    FL   99000000      462819   59151

# %%
merged_in_pop_nba_df.to_csv("nhl_pop_income_city.csv", encoding="utf-8", index=False)

# %%
pop_df['City Name'] = pop_df['City Name'].str.strip()
income_df['City Name'] = income_df['City Name'].str.strip()
pop_df.info()

# %%
merged_df = pd.merge(pop_df, income_df, how='inner', on = ['City Name'])
merged_df.drop(columns = ['State Name_x'], inplace = True)

merged_df

# %%
merged_df['State'] = merged_df['State Name_y']
merged_df['City'] = merged_df['City Name']
merged_df.drop(columns = ['State Name_y'], inplace = True)
merged_df = merged_df.dropna(how='any')
column_names = ["Population", "Income", "City", "State"]
merged_df = merged_df.reindex(columns=column_names)

income_df.reset_index()

# %%
merged_df.tail(50)

# %%
merged_df = pd.DataFrame(merged_df)
result_df = merged_df.drop_duplicates(subset=['City'])
result_df.reset_index()
result_df

# %%
result_df.loc[merged_df['City Name'] == 'Cincinnati']

# %%
result_df.to_csv("pop_income_city.csv", encoding="utf-8", index=False)

# %%
# only 2 cities have the exact same income
