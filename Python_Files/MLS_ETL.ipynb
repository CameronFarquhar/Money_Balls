# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st
from datetime import date
from functools import reduce
import json
import ctypes
import seaborn as sns
import datetime

# %%
df = pd.read_csv('../Data/SUB-IP-EST2019-ANNRNK-1.csv')
# df['City Name'] = df['Geographic Area'].str.split(', ').apply(lambda x: x[0])
df.dropna()
df['2018'] = df['2018'].astype('int64')
# df['Geographic Area'] = df['Geographic Area'].astype('str')
df.dtypes
# Out:
# Geographic Area    object
# 2018                int64
# dtype: object

# %%
df['City Name'] = df['Geographic Area'].str.split(', ').apply(lambda x: x[0])
df['State Name'] = df['Geographic Area'].str.split(', ').apply(lambda x: x[-1])
df['City Name'] = df['City Name'].str.rstrip('city')
df.rename(columns = {"2018":"Population"}, inplace = True)
df.drop(columns = ["Geographic Area"], inplace = True)
df['City Name'] = df['City Name'].astype(str)
df.reset_index()
# Out:
#      index  Population       City Name     State Name
# 0        0     8390081       New York        New York
# 1        1     3977596    Los Angeles      California
# 2        2     2701423        Chicago        Illinois
# 3        3     2318573        Houston           Texas
# 4        4     1654675        Phoenix         Arizona
# ..     ...         ...             ...            ...
# 783    783       50012       Lakewood            Ohio
# 784    784       49354           Troy        New York
# 785    785       48310        Saginaw        Michigan
# 786    786       48012  Niagara Falls        New York
# 787    787       47172     Charleston   West Virginia
#
# [788 rows x 4 columns]

# %%
df
# Out:
#      Population       City Name     State Name
# 0       8390081       New York        New York
# 1       3977596    Los Angeles      California
# 2       2701423        Chicago        Illinois
# 3       2318573        Houston           Texas
# 4       1654675        Phoenix         Arizona
# ..          ...             ...            ...
# 783       50012       Lakewood            Ohio
# 784       49354           Troy        New York
# 785       48310        Saginaw        Michigan
# 786       48012  Niagara Falls        New York
# 787       47172     Charleston   West Virginia
#
# [788 rows x 3 columns]

# %%
# code coppied from https://gist.github.com/rogerallen/1583593
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}

# %%
df['State Name'] = df['State Name'].map(us_state_abbrev).fillna(df['State Name'])
df
# Out:
#      Population       City Name State Name
# 0       8390081       New York          NY
# 1       3977596    Los Angeles          CA
# 2       2701423        Chicago          IL
# 3       2318573        Houston          TX
# 4       1654675        Phoenix          AZ
# ..          ...             ...        ...
# 783       50012       Lakewood          OH
# 784       49354           Troy          NY
# 785       48310        Saginaw          MI
# 786       48012  Niagara Falls          NY
# 787       47172     Charleston          WV
#
# [788 rows x 3 columns]

# %%
us_state_abbrev = {state: abbrev for abbrev, state in us_state_abbrev.items()}
df['State'] = df['State Name'].map(us_state_abbrev)
df
# Out:
#      Population       City Name State Name          State
# 0       8390081       New York          NY       New York
# 1       3977596    Los Angeles          CA     California
# 2       2701423        Chicago          IL       Illinois
# 3       2318573        Houston          TX          Texas
# 4       1654675        Phoenix          AZ        Arizona
# ..          ...             ...        ...            ...
# 783       50012       Lakewood          OH           Ohio
# 784       49354           Troy          NY       New York
# 785       48310        Saginaw          MI       Michigan
# 786       48012  Niagara Falls          NY       New York
# 787       47172     Charleston          WV  West Virginia
#
# [788 rows x 4 columns]

# %%
df.drop(columns = ['State'], inplace = True)
df.rename(columns = {"City Name":"City"}, inplace = True)
pop_df = df

# %%
df.loc[df['City'] == 'Indianapolis']
# Out:
# Empty DataFrame
# Columns: [Population, City, State Name]
# Index: []

# %%
nba_df = pd.read_csv('../Data/MLS-revenue-2018.csv')
nba_df
# Out:
#                       Team           City State/Province   Revenue
# 0           Atlanta United        Atlanta             GA  47000000
# 1                LA Galaxy    Los Angeles             CA  63000000
# 2         Seattle Sounders        Seattle             WA  52000000
# 3               Toronto FC        Toronto             ON  49000000
# 4         Portland Timbers       Portland             OR  48000000
# 5         New York City FC  New York City             NY  42000000
# 6          Orlando City SC        Orlando             FL  44000000
# 7     Sporting Kansas City    Kansas City             MO  41000000
# 8              D.C. United     Washington             DC  26000000
# 9       New York Red Bulls       Harrison             NY  38000000
# 10        Minnesota United     Saint Paul             MN  24000000
# 11            Chicago Fire        Chicago             IL  27000000
# 12    San Jose Earthquakes       San Jose             CA  36000000
# 13  New England Revolution         Boston             MA  28000000
# 14          Houston Dynamo        Houston             TX  28000000
# 15               FC Dallas         Dallas             TX  34000000
# 16      Philadelphia Union   Philadelphia             PA  26000000
# 17          Real Salt Lake      Salt Lake             UT  22000000
# 18         Montreal Impact       Montreal             QC  24000000
# 19     Vancouver Whitecaps      Vancouver             BC  22000000
# 20           Columbus Crew       Columbus             OH  24000000
# 21         Colorado Rapids         Denver             CO  18000000

# %%
pop_df['City'] = pop_df['City'].str.strip()
nba_df['City'] = nba_df['City'].str.strip()
nba_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Team            22 non-null     object
#  1   City            22 non-null     object
#  2   State/Province  22 non-null     object
#  3   Revenue         22 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 832.0+ bytes

# %%
merged_nba_df = pd.merge(nba_df, pop_df, how='inner', on = ['City'])

# %% [markdown]
# merged_nba_df

# %%
merged_nba_df
# Out:
#                       Team          City State/Province   Revenue  Population  \
# 0           Atlanta United       Atlanta             GA  47000000      498183
# 1                LA Galaxy   Los Angeles             CA  63000000     3977596
# 2         Seattle Sounders       Seattle             WA  52000000      742235
# 3         Portland Timbers      Portland             OR  48000000      650837
# 4         Portland Timbers      Portland             OR  48000000       66405
# 5          Orlando City SC       Orlando             FL  44000000      285903
# 6     Sporting Kansas City   Kansas City             MO  41000000      492012
# 7     Sporting Kansas City   Kansas City             MO  41000000      152965
# 8              D.C. United    Washington             DC  26000000      701547
# 9             Chicago Fire       Chicago             IL  27000000     2701423
# 10    San Jose Earthquakes      San Jose             CA  36000000     1028020
# 11  New England Revolution        Boston             MA  28000000      691147
# 12          Houston Dynamo       Houston             TX  28000000     2318573
# 13               FC Dallas        Dallas             TX  34000000     1341802
# 14      Philadelphia Union  Philadelphia             PA  26000000     1583592
# 15     Vancouver Whitecaps     Vancouver             BC  22000000      182887
# 16           Columbus Crew      Columbus             OH  24000000      890869
# 17           Columbus Crew      Columbus             OH  24000000      194169
# 18         Colorado Rapids        Denver             CO  18000000      716265
#
#    State Name
# 0          GA
# 1          CA
# 2          WA
# 3          OR
# 4          ME
# 5          FL
# 6          MO
# 7          KS
# 8          DC
# 9          IL
# 10         CA
# 11         MA
# 12         TX
# 13         TX
# 14         PA
# 15         WA
# 16         OH
# 17         GA
# 18         CO

# %%
# merged_nba_df = merged_nba_df.loc[merged_nba_df['State Name'] != 'ME']
# merged_nba_df.reset_index()
# merged_nba_df
# cleaned_merged_nba_df = merged_nba_df.drop(merged_nba_df.index[14])
cleaned_merged_nba_df.reset_index()
# merged_nba_df.drop(columns = ["index"], inplace = True)
cleaned_merged_nba_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-8d2f5564d456> in <module>
#       3 # merged_nba_df
#       4 # cleaned_merged_nba_df = merged_nba_df.drop(merged_nba_df.index[14])
# ----> 5 cleaned_merged_nba_df.reset_index()
#       6 # merged_nba_df.drop(columns = ["index"], inplace = True)
#       7 cleaned_merged_nba_df
#
# NameError: name 'cleaned_merged_nba_df' is not defined

# %%
# df.to_csv("pop_cities.csv", encoding="utf-8", index=False)

# %%
income_df = pd.read_csv('../Data/lapi1120msa-1.csv')
income_df.dropna()
income_df['Income'] = income_df['2018.00'].astype('int64')
income_df = income_df.dropna(how='any')
income_df.drop(columns = ['2018.00'], inplace = True)
income_df.reset_index()
income_df
# Out:
#         Metropolitan Statistical Areas  Income
# 0                          Abilene, TX   43585
# 1                            Akron, OH   49556
# 2                           Albany, GA   38034
# 3                   Albany-Lebanon, OR   43327
# 4          Albany-Schenectady-Troy, NY   58443
# ..                                 ...     ...
# 379                         Yakima, WA   43905
# 380                   York-Hanover, PA   49888
# 381  Youngstown-Warren-Boardman, OH-PA   42255
# 382                      Yuba City, CA   43662
# 383                           Yuma, AZ   35012
#
# [384 rows x 2 columns]

# %%
income_df['City Name'] = income_df['Metropolitan Statistical Areas'].str.split(', ').apply(lambda x: x[0])
income_df['State Name'] = income_df['Metropolitan Statistical Areas'].str.split(', ').apply(lambda x: x[-1])
income_df.drop(columns = ['Metropolitan Statistical Areas'], inplace = True)
income_df.reset_index()
# Out:
#      index  Income                   City Name State Name
# 0        0   43585                     Abilene         TX
# 1        1   49556                       Akron         OH
# 2        2   38034                      Albany         GA
# 3        3   43327              Albany-Lebanon         OR
# 4        4   58443     Albany-Schenectady-Troy         NY
# ..     ...     ...                         ...        ...
# 379    379   43905                      Yakima         WA
# 380    380   49888                York-Hanover         PA
# 381    381   42255  Youngstown-Warren-Boardman      OH-PA
# 382    382   43662                   Yuba City         CA
# 383    383   35012                        Yuma         AZ
#
# [384 rows x 4 columns]

# %%
# code found at https://riptutorial.com/pandas/example/25462/split--reshape--csv-strings-in-columns-into-multiple-rows--having-one-element-per-row

reshaped_city = \
(income_df.set_index(income_df.columns.drop('City Name',1).tolist())
   ['City Name'].str.split('-', expand=True)
   .stack()
   .reset_index()
   .rename(columns={0:'City Name'})
   .loc[:, income_df.columns]
)

reshaped_city
# Out:
#      Income   City Name State Name
# 0     43585     Abilene         TX
# 1     49556       Akron         OH
# 2     38034      Albany         GA
# 3     43327      Albany         OR
# 4     43327     Lebanon         OR
# ..      ...         ...        ...
# 579   42255  Youngstown      OH-PA
# 580   42255      Warren      OH-PA
# 581   42255    Boardman      OH-PA
# 582   43662   Yuba City         CA
# 583   35012        Yuma         AZ
#
# [584 rows x 3 columns]

# %%
reshaped_state = \
(reshaped_city.set_index(reshaped_city.columns.drop('State Name',1).tolist())
   ['State Name'].str.split('-', expand=True)
   .stack()
   .reset_index()
   .rename(columns={0:'State Name'})
   .loc[:, reshaped_city.columns]
)

reshaped_state
# Out:
#      Income  City Name State Name
# 0     43585    Abilene         TX
# 1     49556      Akron         OH
# 2     38034     Albany         GA
# 3     43327     Albany         OR
# 4     43327    Lebanon         OR
# ..      ...        ...        ...
# 683   42255     Warren         PA
# 684   42255   Boardman         OH
# 685   42255   Boardman         PA
# 686   43662  Yuba City         CA
# 687   35012       Yuma         AZ
#
# [688 rows x 3 columns]

# %%
city_income_df = reshaped_state

# %%
city_income_df.rename(columns = {"City Name":"City"}, inplace = True)
city_income_df
# Out:
#      Income       City State Name
# 0     43585    Abilene         TX
# 1     49556      Akron         OH
# 2     38034     Albany         GA
# 3     43327     Albany         OR
# 4     43327    Lebanon         OR
# ..      ...        ...        ...
# 683   42255     Warren         PA
# 684   42255   Boardman         OH
# 685   42255   Boardman         PA
# 686   43662  Yuba City         CA
# 687   35012       Yuma         AZ
#
# [688 rows x 3 columns]

# %%
merged_nba_df['City'] = merged_nba_df['City'].str.strip()
city_income_df['City'] = city_income_df['City'].str.strip()
pop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 788 entries, 0 to 787
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Population  788 non-null    int64
#  1   City        788 non-null    object
#  2   State Name  788 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 18.6+ KB

# %%
merged_in_pop_nba_df = pd.merge(merged_nba_df, city_income_df, how='inner', on = ['City'])
merged_in_pop_nba_df
# Out:
#                       Team          City State/Province   Revenue  Population  \
# 0           Atlanta United       Atlanta             GA  47000000      498183
# 1                LA Galaxy   Los Angeles             CA  63000000     3977596
# 2         Seattle Sounders       Seattle             WA  52000000      742235
# 3         Portland Timbers      Portland             OR  48000000      650837
# 4         Portland Timbers      Portland             OR  48000000      650837
# 5         Portland Timbers      Portland             OR  48000000      650837
# 6         Portland Timbers      Portland             OR  48000000       66405
# 7         Portland Timbers      Portland             OR  48000000       66405
# 8         Portland Timbers      Portland             OR  48000000       66405
# 9          Orlando City SC       Orlando             FL  44000000      285903
# 10    Sporting Kansas City   Kansas City             MO  41000000      492012
# 11    Sporting Kansas City   Kansas City             MO  41000000      492012
# 12    Sporting Kansas City   Kansas City             MO  41000000      152965
# 13    Sporting Kansas City   Kansas City             MO  41000000      152965
# 14             D.C. United    Washington             DC  26000000      701547
# 15             D.C. United    Washington             DC  26000000      701547
# 16             D.C. United    Washington             DC  26000000      701547
# 17             D.C. United    Washington             DC  26000000      701547
# 18            Chicago Fire       Chicago             IL  27000000     2701423
# 19            Chicago Fire       Chicago             IL  27000000     2701423
# 20            Chicago Fire       Chicago             IL  27000000     2701423
# 21    San Jose Earthquakes      San Jose             CA  36000000     1028020
# 22  New England Revolution        Boston             MA  28000000      691147
# 23  New England Revolution        Boston             MA  28000000      691147
# 24          Houston Dynamo       Houston             TX  28000000     2318573
# 25               FC Dallas        Dallas             TX  34000000     1341802
# 26      Philadelphia Union  Philadelphia             PA  26000000     1583592
# 27      Philadelphia Union  Philadelphia             PA  26000000     1583592
# 28      Philadelphia Union  Philadelphia             PA  26000000     1583592
# 29      Philadelphia Union  Philadelphia             PA  26000000     1583592
# 30     Vancouver Whitecaps     Vancouver             BC  22000000      182887
# 31     Vancouver Whitecaps     Vancouver             BC  22000000      182887
# 32           Columbus Crew      Columbus             OH  24000000      890869
# 33           Columbus Crew      Columbus             OH  24000000      890869
# 34           Columbus Crew      Columbus             OH  24000000      890869
# 35           Columbus Crew      Columbus             OH  24000000      890869
# 36           Columbus Crew      Columbus             OH  24000000      194169
# 37           Columbus Crew      Columbus             OH  24000000      194169
# 38           Columbus Crew      Columbus             OH  24000000      194169
# 39           Columbus Crew      Columbus             OH  24000000      194169
# 40         Colorado Rapids        Denver             CO  18000000      716265
#
#    State Name_x  Income State Name_y
# 0            GA   53188           GA
# 1            CA   63886           CA
# 2            WA   74815           WA
# 3            OR   57913           ME
# 4            OR   57903           OR
# 5            OR   57903           WA
# 6            ME   57913           ME
# 7            ME   57903           OR
# 8            ME   57903           WA
# 9            FL   43717           FL
# 10           MO   53484           MO
# 11           MO   53484           KS
# 12           KS   53484           MO
# 13           KS   53484           KS
# 14           DC   72340           DC
# 15           DC   72340           VA
# 16           DC   72340           MD
# 17           DC   72340           WV
# 18           IL   61642           IL
# 19           IL   61642           IN
# 20           IL   61642           WI
# 21           CA  108565           CA
# 22           MA   78923           MA
# 23           MA   78923           NH
# 24           TX   57154           TX
# 25           TX   56864           TX
# 26           PA   64228           PA
# 27           PA   64228           NJ
# 28           PA   64228           DE
# 29           PA   64228           MD
# 30           WA   57903           OR
# 31           WA   57903           WA
# 32           OH   40980           GA
# 33           OH   40980           AL
# 34           OH   51234           IN
# 35           OH   51114           OH
# 36           GA   40980           GA
# 37           GA   40980           AL
# 38           GA   51234           IN
# 39           GA   51114           OH
# 40           CO   64690           CO

# %%
merged_in_pop_nba_df = merged_in_pop_nba_df.drop_duplicates(subset=['Team'])
merged_in_pop_nba_df.reset_index()
# Out:
#     index                    Team          City State/Province   Revenue  \
# 0       0          Atlanta United       Atlanta             GA  47000000
# 1       1               LA Galaxy   Los Angeles             CA  63000000
# 2       2        Seattle Sounders       Seattle             WA  52000000
# 3       3        Portland Timbers      Portland             OR  48000000
# 4       9         Orlando City SC       Orlando             FL  44000000
# 5      10    Sporting Kansas City   Kansas City             MO  41000000
# 6      14             D.C. United    Washington             DC  26000000
# 7      18            Chicago Fire       Chicago             IL  27000000
# 8      21    San Jose Earthquakes      San Jose             CA  36000000
# 9      22  New England Revolution        Boston             MA  28000000
# 10     24          Houston Dynamo       Houston             TX  28000000
# 11     25               FC Dallas        Dallas             TX  34000000
# 12     26      Philadelphia Union  Philadelphia             PA  26000000
# 13     30     Vancouver Whitecaps     Vancouver             BC  22000000
# 14     32           Columbus Crew      Columbus             OH  24000000
# 15     40         Colorado Rapids        Denver             CO  18000000
#
#     Population State Name_x  Income State Name_y
# 0       498183           GA   53188           GA
# 1      3977596           CA   63886           CA
# 2       742235           WA   74815           WA
# 3       650837           OR   57913           ME
# 4       285903           FL   43717           FL
# 5       492012           MO   53484           MO
# 6       701547           DC   72340           DC
# 7      2701423           IL   61642           IL
# 8      1028020           CA  108565           CA
# 9       691147           MA   78923           MA
# 10     2318573           TX   57154           TX
# 11     1341802           TX   56864           TX
# 12     1583592           PA   64228           PA
# 13      182887           WA   57903           OR
# 14      890869           OH   40980           GA
# 15      716265           CO   64690           CO

# %%
merged_in_pop_nba_df.sort_values("Team")
# Out:
#                       Team          City State/Province   Revenue  Population  \
# 0           Atlanta United       Atlanta             GA  47000000      498183
# 18            Chicago Fire       Chicago             IL  27000000     2701423
# 40         Colorado Rapids        Denver             CO  18000000      716265
# 32           Columbus Crew      Columbus             OH  24000000      890869
# 14             D.C. United    Washington             DC  26000000      701547
# 25               FC Dallas        Dallas             TX  34000000     1341802
# 24          Houston Dynamo       Houston             TX  28000000     2318573
# 1                LA Galaxy   Los Angeles             CA  63000000     3977596
# 22  New England Revolution        Boston             MA  28000000      691147
# 9          Orlando City SC       Orlando             FL  44000000      285903
# 26      Philadelphia Union  Philadelphia             PA  26000000     1583592
# 3         Portland Timbers      Portland             OR  48000000      650837
# 21    San Jose Earthquakes      San Jose             CA  36000000     1028020
# 2         Seattle Sounders       Seattle             WA  52000000      742235
# 10    Sporting Kansas City   Kansas City             MO  41000000      492012
# 30     Vancouver Whitecaps     Vancouver             BC  22000000      182887
#
#    State Name_x  Income State Name_y
# 0            GA   53188           GA
# 18           IL   61642           IL
# 40           CO   64690           CO
# 32           OH   40980           GA
# 14           DC   72340           DC
# 25           TX   56864           TX
# 24           TX   57154           TX
# 1            CA   63886           CA
# 22           MA   78923           MA
# 9            FL   43717           FL
# 26           PA   64228           PA
# 3            OR   57913           ME
# 21           CA  108565           CA
# 2            WA   74815           WA
# 10           MO   53484           MO
# 30           WA   57903           OR

# %%
merged_in_pop_nba_df.rename(columns = {"State/Province":"State"}, inplace = True)
merged_in_pop_nba_df.drop(columns = ["State Name_x"], inplace = True)
merged_in_pop_nba_df.drop(columns = ["State Name_y"], inplace = True)
merged_in_pop_nba_df
# Out:
# C:\Users\camer\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# C:\Users\camer\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                       Team          City State   Revenue  Population  Income
# 0           Atlanta United       Atlanta    GA  47000000      498183   53188
# 1                LA Galaxy   Los Angeles    CA  63000000     3977596   63886
# 2         Seattle Sounders       Seattle    WA  52000000      742235   74815
# 3         Portland Timbers      Portland    OR  48000000      650837   57913
# 9          Orlando City SC       Orlando    FL  44000000      285903   43717
# 10    Sporting Kansas City   Kansas City    MO  41000000      492012   53484
# 14             D.C. United    Washington    DC  26000000      701547   72340
# 18            Chicago Fire       Chicago    IL  27000000     2701423   61642
# 21    San Jose Earthquakes      San Jose    CA  36000000     1028020  108565
# 22  New England Revolution        Boston    MA  28000000      691147   78923
# 24          Houston Dynamo       Houston    TX  28000000     2318573   57154
# 25               FC Dallas        Dallas    TX  34000000     1341802   56864
# 26      Philadelphia Union  Philadelphia    PA  26000000     1583592   64228
# 30     Vancouver Whitecaps     Vancouver    BC  22000000      182887   57903
# 32           Columbus Crew      Columbus    OH  24000000      890869   40980
# 40         Colorado Rapids        Denver    CO  18000000      716265   64690

# %%
merged_in_pop_nba_df.to_csv("mls_pop_income_city.csv", encoding="utf-8", index=False)

# %%
pop_df['City Name'] = pop_df['City Name'].str.strip()
income_df['City Name'] = income_df['City Name'].str.strip()
pop_df.info()

# %%
merged_df = pd.merge(pop_df, income_df, how='inner', on = ['City Name'])
merged_df.drop(columns = ['State Name_x'], inplace = True)

merged_df

# %%
merged_df['State'] = merged_df['State Name_y']
merged_df['City'] = merged_df['City Name']
merged_df.drop(columns = ['State Name_y'], inplace = True)
merged_df = merged_df.dropna(how='any')
column_names = ["Population", "Income", "City", "State"]
merged_df = merged_df.reindex(columns=column_names)

income_df.reset_index()

# %%
merged_df.tail(50)

# %%
merged_df = pd.DataFrame(merged_df)
result_df = merged_df.drop_duplicates(subset=['City'])
result_df.reset_index()
result_df

# %%
result_df.loc[merged_df['City Name'] == 'Cincinnati']

# %%
result_df.to_csv("pop_income_city.csv", encoding="utf-8", index=False)

# %%
# only 2 cities have the exact same income
