# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st
from datetime import date
from functools import reduce
import json
import ctypes
import seaborn as sns
import datetime

# %%
df = pd.read_csv('Data/SUB-IP-EST2019-ANNRNK-1.csv')
# df['City Name'] = df['Geographic Area'].str.split(', ').apply(lambda x: x[0])
df.dropna()
df['2018'] = df['2018'].astype('int64')
# df['Geographic Area'] = df['Geographic Area'].astype('str')
df.dtypes
# Out:
# Geographic Area    object
# 2018                int64
# dtype: object

# %%
df['City Name'] = df['Geographic Area'].str.split(', ').apply(lambda x: x[0])
df['State Name'] = df['Geographic Area'].str.split(', ').apply(lambda x: x[-1])
df['City Name'] = df['City Name'].str.rstrip('city')
df.rename(columns = {"2018":"Population"}, inplace = True)
df.drop(columns = ["Geographic Area"], inplace = True)
df['City Name'] = df['City Name'].astype(str)
df.reset_index()
# Out:
#      index  Population       City Name     State Name
# 0        0     8390081       New York        New York
# 1        1     3977596    Los Angeles      California
# 2        2     2701423        Chicago        Illinois
# 3        3     2318573        Houston           Texas
# 4        4     1654675        Phoenix         Arizona
# ..     ...         ...             ...            ...
# 783    783       50012       Lakewood            Ohio
# 784    784       49354           Troy        New York
# 785    785       48310        Saginaw        Michigan
# 786    786       48012  Niagara Falls        New York
# 787    787       47172     Charleston   West Virginia
#
# [788 rows x 4 columns]

# %%
df
# Out:
#      Population       City Name     State Name
# 0       8390081       New York        New York
# 1       3977596    Los Angeles      California
# 2       2701423        Chicago        Illinois
# 3       2318573        Houston           Texas
# 4       1654675        Phoenix         Arizona
# ..          ...             ...            ...
# 783       50012       Lakewood            Ohio
# 784       49354           Troy        New York
# 785       48310        Saginaw        Michigan
# 786       48012  Niagara Falls        New York
# 787       47172     Charleston   West Virginia
#
# [788 rows x 3 columns]

# %%
# code coppied from https://gist.github.com/rogerallen/1583593
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}

# %%
df['State Name'] = df['State Name'].map(us_state_abbrev).fillna(df['State Name'])
df
# Out:
#      Population       City Name State Name
# 0       8390081       New York          NY
# 1       3977596    Los Angeles          CA
# 2       2701423        Chicago          IL
# 3       2318573        Houston          TX
# 4       1654675        Phoenix          AZ
# ..          ...             ...        ...
# 783       50012       Lakewood          OH
# 784       49354           Troy          NY
# 785       48310        Saginaw          MI
# 786       48012  Niagara Falls          NY
# 787       47172     Charleston          WV
#
# [788 rows x 3 columns]

# %%
us_state_abbrev = {state: abbrev for abbrev, state in us_state_abbrev.items()}
df['State'] = df['State Name'].map(us_state_abbrev)
df
# Out:
#      Population       City Name State Name          State
# 0       8390081       New York          NY       New York
# 1       3977596    Los Angeles          CA     California
# 2       2701423        Chicago          IL       Illinois
# 3       2318573        Houston          TX          Texas
# 4       1654675        Phoenix          AZ        Arizona
# ..          ...             ...        ...            ...
# 783       50012       Lakewood          OH           Ohio
# 784       49354           Troy          NY       New York
# 785       48310        Saginaw          MI       Michigan
# 786       48012  Niagara Falls          NY       New York
# 787       47172     Charleston          WV  West Virginia
#
# [788 rows x 4 columns]

# %%
df.drop(columns = ['State'], inplace = True)
df.rename(columns = {"City Name":"City"}, inplace = True)
pop_df = df

# %%
df.loc[df['City'] == 'Indianapolis']
# Out:
# Empty DataFrame
# Columns: [Population, City, State Name]
# Index: []

# %%
nba_df = pd.read_csv('Data/NBA-revenue-2018.csv')
nba_df
# Out:
#                       Team            City State/Province     Revenue
# 0          New York Knicks        New York             NY  3600000000
# 1       Los Angeles Lakers     Los Angeles             CA  3300000000
# 2    Golden State Warriors   San Francisco             CA  3100000000
# 3            Chicago Bulls         Chicago             IL  2600000000
# 4           Boston Celtics          Boston             MA  2500000000
# 5            Brooklyn Nets        New York             NY  2300000000
# 6          Houston Rockets         Houston             TX  2200000000
# 7     Los Angeles Clippers     Los Angeles             CA  2150000000
# 8         Dallas Mavericks          Dallas             TX  1900000000
# 9               Miami Heat           Miami             FL  1700000000
# 10       San Antonio Spurs     San Antonio             TX  1550000000
# 11         Toronto Raptors         Toronto             ON  1400000000
# 12        Sacramento Kings      Sacramento             CA  1375000000
# 13      Washington Wizards      Washington             DC  1350000000
# 14     Cleveland Cavaliers       Cleveland             OH  1325000000
# 15  Portland Trail Blazers        Portland             OR  1300000000
# 16            Phoenix Suns         Phoenix             AZ  1280000000
# 17   Oklahoma City Thunder   Oklahoma City             OK  1250000000
# 18           Orlando Magic         Orlando             FL  1225000000
# 19               Utah Jazz  Salt Lake City             UT  1200000000
# 20      Philadelphia 76ers    Philadelphia             PA  1180000000
# 21          Indiana Pacers    Indianapolis             IN  1175000000
# 22           Atlanta Hawks         Atlanta             GA  1150000000
# 23          Denver Nuggets          Denver             CO  1125000000
# 24         Detroit Pistons         Detroit             MI  1100000000
# 25         Milwaukee Bucks       Milwaukee             WI  1075000000
# 26  Minnesota Timberwolves     Minneapolis             MN  1060000000
# 27       Charlotte Hornets       Charlotte             NC  1050000000
# 28       Memphis Grizzlies         Memphis             TN  1025000000
# 29    New Orleans Pelicans     New Orleans             LA  1000000000

# %%
pop_df['City'] = pop_df['City'].str.strip()
nba_df['City'] = nba_df['City'].str.strip()
nba_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Team            30 non-null     object
#  1   City            30 non-null     object
#  2   State/Province  30 non-null     object
#  3   Revenue         30 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 1.1+ KB

# %%
merged_nba_df = pd.merge(nba_df, pop_df, how='inner', on = ['City'])

# %% [markdown]
# merged_nba_df

# %%
merged_nba_df
# Out:
#                       Team            City State/Province     Revenue  \
# 0          New York Knicks        New York             NY  3600000000
# 1            Brooklyn Nets        New York             NY  2300000000
# 2       Los Angeles Lakers     Los Angeles             CA  3300000000
# 3     Los Angeles Clippers     Los Angeles             CA  2150000000
# 4    Golden State Warriors   San Francisco             CA  3100000000
# 5            Chicago Bulls         Chicago             IL  2600000000
# 6           Boston Celtics          Boston             MA  2500000000
# 7          Houston Rockets         Houston             TX  2200000000
# 8         Dallas Mavericks          Dallas             TX  1900000000
# 9               Miami Heat           Miami             FL  1700000000
# 10       San Antonio Spurs     San Antonio             TX  1550000000
# 11        Sacramento Kings      Sacramento             CA  1375000000
# 12      Washington Wizards      Washington             DC  1350000000
# 13     Cleveland Cavaliers       Cleveland             OH  1325000000
# 14  Portland Trail Blazers        Portland             OR  1300000000
# 15  Portland Trail Blazers        Portland             OR  1300000000
# 16            Phoenix Suns         Phoenix             AZ  1280000000
# 17   Oklahoma City Thunder   Oklahoma City             OK  1250000000
# 18           Orlando Magic         Orlando             FL  1225000000
# 19               Utah Jazz  Salt Lake City             UT  1200000000
# 20      Philadelphia 76ers    Philadelphia             PA  1180000000
# 21           Atlanta Hawks         Atlanta             GA  1150000000
# 22          Denver Nuggets          Denver             CO  1125000000
# 23         Detroit Pistons         Detroit             MI  1100000000
# 24         Milwaukee Bucks       Milwaukee             WI  1075000000
# 25  Minnesota Timberwolves     Minneapolis             MN  1060000000
# 26       Charlotte Hornets       Charlotte             NC  1050000000
# 27       Memphis Grizzlies         Memphis             TN  1025000000
# 28    New Orleans Pelicans     New Orleans             LA  1000000000
#
#     Population State Name
# 0      8390081         NY
# 1      8390081         NY
# 2      3977596         CA
# 3      3977596         CA
# 4       880696         CA
# 5      2701423         IL
# 6       691147         MA
# 7      2318573         TX
# 8      1341802         TX
# 9       462819         FL
# 10     1530016         TX
# 11      507737         CA
# 12      701547         DC
# 13      383214         OH
# 14      650837         OR
# 15       66405         ME
# 16     1654675         AZ
# 17      647912         OK
# 18      285903         FL
# 19      200435         UT
# 20     1583592         PA
# 21      498183         GA
# 22      716265         CO
# 23      672977         MI
# 24      591375         WI
# 25      424903         MN
# 26      872514         NC
# 27      651104         TN
# 28      391004         LA

# %%
# merged_nba_df = merged_nba_df.loc[merged_nba_df['State Name'] != 'ME']
# merged_nba_df.reset_index()
# merged_nba_df
cleaned_merged_nba_df = merged_nba_df.drop(merged_nba_df.index[14])
cleaned_merged_nba_df.reset_index()
# merged_nba_df.drop(columns = ["index"], inplace = True)
cleaned_merged_nba_df
# Out:
#                       Team            City State/Province     Revenue  \
# 0          New York Knicks        New York             NY  3600000000
# 1            Brooklyn Nets        New York             NY  2300000000
# 2       Los Angeles Lakers     Los Angeles             CA  3300000000
# 3     Los Angeles Clippers     Los Angeles             CA  2150000000
# 4    Golden State Warriors   San Francisco             CA  3100000000
# 5            Chicago Bulls         Chicago             IL  2600000000
# 6           Boston Celtics          Boston             MA  2500000000
# 7          Houston Rockets         Houston             TX  2200000000
# 8         Dallas Mavericks          Dallas             TX  1900000000
# 9               Miami Heat           Miami             FL  1700000000
# 10       San Antonio Spurs     San Antonio             TX  1550000000
# 11        Sacramento Kings      Sacramento             CA  1375000000
# 12      Washington Wizards      Washington             DC  1350000000
# 13     Cleveland Cavaliers       Cleveland             OH  1325000000
# 15  Portland Trail Blazers        Portland             OR  1300000000
# 16            Phoenix Suns         Phoenix             AZ  1280000000
# 17   Oklahoma City Thunder   Oklahoma City             OK  1250000000
# 18           Orlando Magic         Orlando             FL  1225000000
# 19               Utah Jazz  Salt Lake City             UT  1200000000
# 20      Philadelphia 76ers    Philadelphia             PA  1180000000
# 21           Atlanta Hawks         Atlanta             GA  1150000000
# 22          Denver Nuggets          Denver             CO  1125000000
# 23         Detroit Pistons         Detroit             MI  1100000000
# 24         Milwaukee Bucks       Milwaukee             WI  1075000000
# 25  Minnesota Timberwolves     Minneapolis             MN  1060000000
# 26       Charlotte Hornets       Charlotte             NC  1050000000
# 27       Memphis Grizzlies         Memphis             TN  1025000000
# 28    New Orleans Pelicans     New Orleans             LA  1000000000
#
#     Population State Name
# 0      8390081         NY
# 1      8390081         NY
# 2      3977596         CA
# 3      3977596         CA
# 4       880696         CA
# 5      2701423         IL
# 6       691147         MA
# 7      2318573         TX
# 8      1341802         TX
# 9       462819         FL
# 10     1530016         TX
# 11      507737         CA
# 12      701547         DC
# 13      383214         OH
# 15       66405         ME
# 16     1654675         AZ
# 17      647912         OK
# 18      285903         FL
# 19      200435         UT
# 20     1583592         PA
# 21      498183         GA
# 22      716265         CO
# 23      672977         MI
# 24      591375         WI
# 25      424903         MN
# 26      872514         NC
# 27      651104         TN
# 28      391004         LA

# %%
# df.to_csv("pop_cities.csv", encoding="utf-8", index=False)

# %%
income_df = pd.read_csv('Data/lapi1120msa-1.csv')
income_df.dropna()
income_df['Income'] = income_df['2018.00'].astype('int64')
income_df = income_df.dropna(how='any')
income_df.drop(columns = ['2018.00'], inplace = True)
income_df.reset_index()
income_df
# Out:
#         Metropolitan Statistical Areas  Income
# 0                          Abilene, TX   43585
# 1                            Akron, OH   49556
# 2                           Albany, GA   38034
# 3                   Albany-Lebanon, OR   43327
# 4          Albany-Schenectady-Troy, NY   58443
# ..                                 ...     ...
# 379                         Yakima, WA   43905
# 380                   York-Hanover, PA   49888
# 381  Youngstown-Warren-Boardman, OH-PA   42255
# 382                      Yuba City, CA   43662
# 383                           Yuma, AZ   35012
#
# [384 rows x 2 columns]

# %%
income_df['City Name'] = income_df['Metropolitan Statistical Areas'].str.split(', ').apply(lambda x: x[0])
income_df['State Name'] = income_df['Metropolitan Statistical Areas'].str.split(', ').apply(lambda x: x[-1])
income_df.drop(columns = ['Metropolitan Statistical Areas'], inplace = True)
income_df.reset_index()
# Out:
#      index  Income                   City Name State Name
# 0        0   43585                     Abilene         TX
# 1        1   49556                       Akron         OH
# 2        2   38034                      Albany         GA
# 3        3   43327              Albany-Lebanon         OR
# 4        4   58443     Albany-Schenectady-Troy         NY
# ..     ...     ...                         ...        ...
# 379    379   43905                      Yakima         WA
# 380    380   49888                York-Hanover         PA
# 381    381   42255  Youngstown-Warren-Boardman      OH-PA
# 382    382   43662                   Yuba City         CA
# 383    383   35012                        Yuma         AZ
#
# [384 rows x 4 columns]

# %%
# code found at https://riptutorial.com/pandas/example/25462/split--reshape--csv-strings-in-columns-into-multiple-rows--having-one-element-per-row

reshaped_city = \
(income_df.set_index(income_df.columns.drop('City Name',1).tolist())
   ['City Name'].str.split('-', expand=True)
   .stack()
   .reset_index()
   .rename(columns={0:'City Name'})
   .loc[:, income_df.columns]
)

reshaped_city
# Out:
#      Income   City Name State Name
# 0     43585     Abilene         TX
# 1     49556       Akron         OH
# 2     38034      Albany         GA
# 3     43327      Albany         OR
# 4     43327     Lebanon         OR
# ..      ...         ...        ...
# 579   42255  Youngstown      OH-PA
# 580   42255      Warren      OH-PA
# 581   42255    Boardman      OH-PA
# 582   43662   Yuba City         CA
# 583   35012        Yuma         AZ
#
# [584 rows x 3 columns]

# %%
reshaped_state = \
(reshaped_city.set_index(reshaped_city.columns.drop('State Name',1).tolist())
   ['State Name'].str.split('-', expand=True)
   .stack()
   .reset_index()
   .rename(columns={0:'State Name'})
   .loc[:, reshaped_city.columns]
)

reshaped_state
# Out:
#      Income  City Name State Name
# 0     43585    Abilene         TX
# 1     49556      Akron         OH
# 2     38034     Albany         GA
# 3     43327     Albany         OR
# 4     43327    Lebanon         OR
# ..      ...        ...        ...
# 683   42255     Warren         PA
# 684   42255   Boardman         OH
# 685   42255   Boardman         PA
# 686   43662  Yuba City         CA
# 687   35012       Yuma         AZ
#
# [688 rows x 3 columns]

# %%
city_income_df = reshaped_state

# %%
city_income_df.rename(columns = {"City Name":"City"}, inplace = True)
city_income_df
# Out:
#      Income       City State Name
# 0     43585    Abilene         TX
# 1     49556      Akron         OH
# 2     38034     Albany         GA
# 3     43327     Albany         OR
# 4     43327    Lebanon         OR
# ..      ...        ...        ...
# 683   42255     Warren         PA
# 684   42255   Boardman         OH
# 685   42255   Boardman         PA
# 686   43662  Yuba City         CA
# 687   35012       Yuma         AZ
#
# [688 rows x 3 columns]

# %%
cleaned_merged_nba_df['City'] = cleaned_merged_nba_df['City'].str.strip()
city_income_df['City'] = city_income_df['City'].str.strip()
pop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 788 entries, 0 to 787
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Population  788 non-null    int64
#  1   City        788 non-null    object
#  2   State Name  788 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 18.6+ KB

# %%
merged_in_pop_nba_df = pd.merge(cleaned_merged_nba_df, city_income_df, how='inner', on = ['City'])
merged_in_pop_nba_df
# Out:
#                       Team            City State/Province     Revenue  \
# 0          New York Knicks        New York             NY  3600000000
# 1          New York Knicks        New York             NY  3600000000
# 2          New York Knicks        New York             NY  3600000000
# 3            Brooklyn Nets        New York             NY  2300000000
# 4            Brooklyn Nets        New York             NY  2300000000
# 5            Brooklyn Nets        New York             NY  2300000000
# 6       Los Angeles Lakers     Los Angeles             CA  3300000000
# 7     Los Angeles Clippers     Los Angeles             CA  2150000000
# 8    Golden State Warriors   San Francisco             CA  3100000000
# 9            Chicago Bulls         Chicago             IL  2600000000
# 10           Chicago Bulls         Chicago             IL  2600000000
# 11           Chicago Bulls         Chicago             IL  2600000000
# 12          Boston Celtics          Boston             MA  2500000000
# 13          Boston Celtics          Boston             MA  2500000000
# 14         Houston Rockets         Houston             TX  2200000000
# 15        Dallas Mavericks          Dallas             TX  1900000000
# 16              Miami Heat           Miami             FL  1700000000
# 17       San Antonio Spurs     San Antonio             TX  1550000000
# 18        Sacramento Kings      Sacramento             CA  1375000000
# 19      Washington Wizards      Washington             DC  1350000000
# 20      Washington Wizards      Washington             DC  1350000000
# 21      Washington Wizards      Washington             DC  1350000000
# 22      Washington Wizards      Washington             DC  1350000000
# 23     Cleveland Cavaliers       Cleveland             OH  1325000000
# 24     Cleveland Cavaliers       Cleveland             OH  1325000000
# 25  Portland Trail Blazers        Portland             OR  1300000000
# 26  Portland Trail Blazers        Portland             OR  1300000000
# 27  Portland Trail Blazers        Portland             OR  1300000000
# 28            Phoenix Suns         Phoenix             AZ  1280000000
# 29   Oklahoma City Thunder   Oklahoma City             OK  1250000000
# 30           Orlando Magic         Orlando             FL  1225000000
# 31               Utah Jazz  Salt Lake City             UT  1200000000
# 32      Philadelphia 76ers    Philadelphia             PA  1180000000
# 33      Philadelphia 76ers    Philadelphia             PA  1180000000
# 34      Philadelphia 76ers    Philadelphia             PA  1180000000
# 35      Philadelphia 76ers    Philadelphia             PA  1180000000
# 36           Atlanta Hawks         Atlanta             GA  1150000000
# 37          Denver Nuggets          Denver             CO  1125000000
# 38         Detroit Pistons         Detroit             MI  1100000000
# 39         Milwaukee Bucks       Milwaukee             WI  1075000000
# 40  Minnesota Timberwolves     Minneapolis             MN  1060000000
# 41  Minnesota Timberwolves     Minneapolis             MN  1060000000
# 42       Charlotte Hornets       Charlotte             NC  1050000000
# 43       Charlotte Hornets       Charlotte             NC  1050000000
# 44       Memphis Grizzlies         Memphis             TN  1025000000
# 45       Memphis Grizzlies         Memphis             TN  1025000000
# 46       Memphis Grizzlies         Memphis             TN  1025000000
# 47    New Orleans Pelicans     New Orleans             LA  1000000000
#
#     Population State Name_x  Income State Name_y
# 0      8390081           NY   76565           NY
# 1      8390081           NY   76565           NJ
# 2      8390081           NY   76565           PA
# 3      8390081           NY   76565           NY
# 4      8390081           NY   76565           NJ
# 5      8390081           NY   76565           PA
# 6      3977596           CA   63886           CA
# 7      3977596           CA   63886           CA
# 8       880696           CA  100236           CA
# 9      2701423           IL   61642           IL
# 10     2701423           IL   61642           IN
# 11     2701423           IL   61642           WI
# 12      691147           MA   78923           MA
# 13      691147           MA   78923           NH
# 14     2318573           TX   57154           TX
# 15     1341802           TX   56864           TX
# 16      462819           FL   59151           FL
# 17     1530016           TX   47349           TX
# 18      507737           CA   56502           CA
# 19      701547           DC   72340           DC
# 20      701547           DC   72340           VA
# 21      701547           DC   72340           MD
# 22      701547           DC   72340           WV
# 23      383214           OH   38594           TN
# 24      383214           OH   53770           OH
# 25       66405           ME   57913           ME
# 26       66405           ME   57903           OR
# 27       66405           ME   57903           WA
# 28     1654675           AZ   46539           AZ
# 29      647912           OK   47607           OK
# 30      285903           FL   43717           FL
# 31      200435           UT   52150           UT
# 32     1583592           PA   64228           PA
# 33     1583592           PA   64228           NJ
# 34     1583592           PA   64228           DE
# 35     1583592           PA   64228           MD
# 36      498183           GA   53188           GA
# 37      716265           CO   64690           CO
# 38      672977           MI   52572           MI
# 39      591375           WI   57034           WI
# 40      424903           MN   62914           MN
# 41      424903           MN   62914           WI
# 42      872514           NC   52295           NC
# 43      872514           NC   52295           SC
# 44      651104           TN   46677           TN
# 45      651104           TN   46677           MS
# 46      651104           TN   46677           AR
# 47      391004           LA   52963           LA

# %%
merged_in_pop_nba_df = merged_in_pop_nba_df.drop_duplicates(subset=['Team'])
merged_in_pop_nba_df.reset_index()
# Out:
#     index                    Team            City State/Province     Revenue  \
# 0       0         New York Knicks        New York             NY  3600000000
# 1       3           Brooklyn Nets        New York             NY  2300000000
# 2       6      Los Angeles Lakers     Los Angeles             CA  3300000000
# 3       7    Los Angeles Clippers     Los Angeles             CA  2150000000
# 4       8   Golden State Warriors   San Francisco             CA  3100000000
# 5       9           Chicago Bulls         Chicago             IL  2600000000
# 6      12          Boston Celtics          Boston             MA  2500000000
# 7      14         Houston Rockets         Houston             TX  2200000000
# 8      15        Dallas Mavericks          Dallas             TX  1900000000
# 9      16              Miami Heat           Miami             FL  1700000000
# 10     17       San Antonio Spurs     San Antonio             TX  1550000000
# 11     18        Sacramento Kings      Sacramento             CA  1375000000
# 12     19      Washington Wizards      Washington             DC  1350000000
# 13     23     Cleveland Cavaliers       Cleveland             OH  1325000000
# 14     25  Portland Trail Blazers        Portland             OR  1300000000
# 15     28            Phoenix Suns         Phoenix             AZ  1280000000
# 16     29   Oklahoma City Thunder   Oklahoma City             OK  1250000000
# 17     30           Orlando Magic         Orlando             FL  1225000000
# 18     31               Utah Jazz  Salt Lake City             UT  1200000000
# 19     32      Philadelphia 76ers    Philadelphia             PA  1180000000
# 20     36           Atlanta Hawks         Atlanta             GA  1150000000
# 21     37          Denver Nuggets          Denver             CO  1125000000
# 22     38         Detroit Pistons         Detroit             MI  1100000000
# 23     39         Milwaukee Bucks       Milwaukee             WI  1075000000
# 24     40  Minnesota Timberwolves     Minneapolis             MN  1060000000
# 25     42       Charlotte Hornets       Charlotte             NC  1050000000
# 26     44       Memphis Grizzlies         Memphis             TN  1025000000
# 27     47    New Orleans Pelicans     New Orleans             LA  1000000000
#
#     Population State Name_x  Income State Name_y
# 0      8390081           NY   76565           NY
# 1      8390081           NY   76565           NY
# 2      3977596           CA   63886           CA
# 3      3977596           CA   63886           CA
# 4       880696           CA  100236           CA
# 5      2701423           IL   61642           IL
# 6       691147           MA   78923           MA
# 7      2318573           TX   57154           TX
# 8      1341802           TX   56864           TX
# 9       462819           FL   59151           FL
# 10     1530016           TX   47349           TX
# 11      507737           CA   56502           CA
# 12      701547           DC   72340           DC
# 13      383214           OH   38594           TN
# 14       66405           ME   57913           ME
# 15     1654675           AZ   46539           AZ
# 16      647912           OK   47607           OK
# 17      285903           FL   43717           FL
# 18      200435           UT   52150           UT
# 19     1583592           PA   64228           PA
# 20      498183           GA   53188           GA
# 21      716265           CO   64690           CO
# 22      672977           MI   52572           MI
# 23      591375           WI   57034           WI
# 24      424903           MN   62914           MN
# 25      872514           NC   52295           NC
# 26      651104           TN   46677           TN
# 27      391004           LA   52963           LA

# %%
merged_in_pop_nba_df.sort_values("Team")
# Out:
#                       Team            City State/Province     Revenue  \
# 36           Atlanta Hawks         Atlanta             GA  1150000000
# 12          Boston Celtics          Boston             MA  2500000000
# 3            Brooklyn Nets        New York             NY  2300000000
# 42       Charlotte Hornets       Charlotte             NC  1050000000
# 9            Chicago Bulls         Chicago             IL  2600000000
# 23     Cleveland Cavaliers       Cleveland             OH  1325000000
# 15        Dallas Mavericks          Dallas             TX  1900000000
# 37          Denver Nuggets          Denver             CO  1125000000
# 38         Detroit Pistons         Detroit             MI  1100000000
# 8    Golden State Warriors   San Francisco             CA  3100000000
# 14         Houston Rockets         Houston             TX  2200000000
# 7     Los Angeles Clippers     Los Angeles             CA  2150000000
# 6       Los Angeles Lakers     Los Angeles             CA  3300000000
# 44       Memphis Grizzlies         Memphis             TN  1025000000
# 16              Miami Heat           Miami             FL  1700000000
# 39         Milwaukee Bucks       Milwaukee             WI  1075000000
# 40  Minnesota Timberwolves     Minneapolis             MN  1060000000
# 47    New Orleans Pelicans     New Orleans             LA  1000000000
# 0          New York Knicks        New York             NY  3600000000
# 29   Oklahoma City Thunder   Oklahoma City             OK  1250000000
# 30           Orlando Magic         Orlando             FL  1225000000
# 32      Philadelphia 76ers    Philadelphia             PA  1180000000
# 28            Phoenix Suns         Phoenix             AZ  1280000000
# 25  Portland Trail Blazers        Portland             OR  1300000000
# 18        Sacramento Kings      Sacramento             CA  1375000000
# 17       San Antonio Spurs     San Antonio             TX  1550000000
# 31               Utah Jazz  Salt Lake City             UT  1200000000
# 19      Washington Wizards      Washington             DC  1350000000
#
#     Population State Name_x  Income State Name_y
# 36      498183           GA   53188           GA
# 12      691147           MA   78923           MA
# 3      8390081           NY   76565           NY
# 42      872514           NC   52295           NC
# 9      2701423           IL   61642           IL
# 23      383214           OH   38594           TN
# 15     1341802           TX   56864           TX
# 37      716265           CO   64690           CO
# 38      672977           MI   52572           MI
# 8       880696           CA  100236           CA
# 14     2318573           TX   57154           TX
# 7      3977596           CA   63886           CA
# 6      3977596           CA   63886           CA
# 44      651104           TN   46677           TN
# 16      462819           FL   59151           FL
# 39      591375           WI   57034           WI
# 40      424903           MN   62914           MN
# 47      391004           LA   52963           LA
# 0      8390081           NY   76565           NY
# 29      647912           OK   47607           OK
# 30      285903           FL   43717           FL
# 32     1583592           PA   64228           PA
# 28     1654675           AZ   46539           AZ
# 25       66405           ME   57913           ME
# 18      507737           CA   56502           CA
# 17     1530016           TX   47349           TX
# 31      200435           UT   52150           UT
# 19      701547           DC   72340           DC

# %%
merged_in_pop_nba_df.rename(columns = {"State/Province":"State"}, inplace = True)
merged_in_pop_nba_df.drop(columns = ["State Name_x"], inplace = True)
merged_in_pop_nba_df.drop(columns = ["State Name_y"], inplace = True)
merged_in_pop_nba_df
# Out:
# C:\Users\camer\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# C:\Users\camer\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                       Team            City State     Revenue  Population  \
# 0          New York Knicks        New York    NY  3600000000     8390081
# 3            Brooklyn Nets        New York    NY  2300000000     8390081
# 6       Los Angeles Lakers     Los Angeles    CA  3300000000     3977596
# 7     Los Angeles Clippers     Los Angeles    CA  2150000000     3977596
# 8    Golden State Warriors   San Francisco    CA  3100000000      880696
# 9            Chicago Bulls         Chicago    IL  2600000000     2701423
# 12          Boston Celtics          Boston    MA  2500000000      691147
# 14         Houston Rockets         Houston    TX  2200000000     2318573
# 15        Dallas Mavericks          Dallas    TX  1900000000     1341802
# 16              Miami Heat           Miami    FL  1700000000      462819
# 17       San Antonio Spurs     San Antonio    TX  1550000000     1530016
# 18        Sacramento Kings      Sacramento    CA  1375000000      507737
# 19      Washington Wizards      Washington    DC  1350000000      701547
# 23     Cleveland Cavaliers       Cleveland    OH  1325000000      383214
# 25  Portland Trail Blazers        Portland    OR  1300000000       66405
# 28            Phoenix Suns         Phoenix    AZ  1280000000     1654675
# 29   Oklahoma City Thunder   Oklahoma City    OK  1250000000      647912
# 30           Orlando Magic         Orlando    FL  1225000000      285903
# 31               Utah Jazz  Salt Lake City    UT  1200000000      200435
# 32      Philadelphia 76ers    Philadelphia    PA  1180000000     1583592
# 36           Atlanta Hawks         Atlanta    GA  1150000000      498183
# 37          Denver Nuggets          Denver    CO  1125000000      716265
# 38         Detroit Pistons         Detroit    MI  1100000000      672977
# 39         Milwaukee Bucks       Milwaukee    WI  1075000000      591375
# 40  Minnesota Timberwolves     Minneapolis    MN  1060000000      424903
# 42       Charlotte Hornets       Charlotte    NC  1050000000      872514
# 44       Memphis Grizzlies         Memphis    TN  1025000000      651104
# 47    New Orleans Pelicans     New Orleans    LA  1000000000      391004
#
#     Income
# 0    76565
# 3    76565
# 6    63886
# 7    63886
# 8   100236
# 9    61642
# 12   78923
# 14   57154
# 15   56864
# 16   59151
# 17   47349
# 18   56502
# 19   72340
# 23   38594
# 25   57913
# 28   46539
# 29   47607
# 30   43717
# 31   52150
# 32   64228
# 36   53188
# 37   64690
# 38   52572
# 39   57034
# 40   62914
# 42   52295
# 44   46677
# 47   52963

# %%
merged_in_pop_nba_df.to_csv("nba_pop_income_city.csv", encoding="utf-8", index=False)

# %%
pop_df['City Name'] = pop_df['City Name'].str.strip()
income_df['City Name'] = income_df['City Name'].str.strip()
pop_df.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'City Name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-130-3f959bbe2c60> in <module>
# ----> 1 pop_df['City Name'] = pop_df['City Name'].str.strip()
#       2 income_df['City Name'] = income_df['City Name'].str.strip()
#       3 pop_df.info()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'City Name'

# %%
merged_df = pd.merge(pop_df, income_df, how='inner', on = ['City Name'])
merged_df.drop(columns = ['State Name_x'], inplace = True)

merged_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-131-56a554b40c7f> in <module>
# ----> 1 merged_df = pd.merge(pop_df, income_df, how='inner', on = ['City Name'])
#       2 merged_df.drop(columns = ['State Name_x'], inplace = True)
#       3
#       4 merged_df
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      84         copy=copy,
#      85         indicator=indicator,
# ---> 86         validate=validate,
#      87     )
#      88     return op.get_result()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     625             self.right_join_keys,
#     626             self.join_names,
# --> 627         ) = self._get_merge_keys()
#     628
#     629         # validate the merge keys dtypes. We may need to coerce
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#     994                         right_keys.append(rk)
#     995                     if lk is not None:
# --> 996                         left_keys.append(left._get_label_or_level_values(lk))
#     997                         join_names.append(lk)
#     998                     else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1690             values = self.axes[axis].get_level_values(key)._values
#    1691         else:
# -> 1692             raise KeyError(key)
#    1693
#    1694         # Check for duplicates
#
# KeyError: 'City Name'

# %%
merged_df['State'] = merged_df['State Name_y']
merged_df['City'] = merged_df['City Name']
merged_df.drop(columns = ['State Name_y'], inplace = True)
merged_df = merged_df.dropna(how='any')
column_names = ["Population", "Income", "City", "State"]
merged_df = merged_df.reindex(columns=column_names)

income_df.reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-132-a1227d399029> in <module>
# ----> 1 merged_df['State'] = merged_df['State Name_y']
#       2 merged_df['City'] = merged_df['City Name']
#       3 merged_df.drop(columns = ['State Name_y'], inplace = True)
#       4 merged_df = merged_df.dropna(how='any')
#       5 column_names = ["Population", "Income", "City", "State"]
#
# NameError: name 'merged_df' is not defined

# %%
merged_df.tail(50)
# Out:
#      Population  Income              City State
# 500       60101   40195           Bristol    TN
# 501       60101   40195           Bristol    VA
# 502       60040   43984             Utica    NY
# 503       57601   57104         Bradenton    FL
# 504       59856   39587          Vineland    NJ
# 505       58969   47070         Corvallis    OR
# 506       58751   47889       Great Falls    MT
# 507       57746   57104          Sarasota    FL
# 508       57533   44548          Richland    WA
# 509       57922   42140            Kokomo    IN
# 510       57515   71324            Casper    WY
# 511       57975   50120           Dubuque    IA
# 512       56971   36961           Hanford    CA
# 513       55982   38310         Pocatello    ID
# 514       56428   36438          Valdosta    GA
# 515       55020   33354  Lake Havasu City    AZ
# 516       56637   50258       Grand Forks    ND
# 517       56637   50258       Grand Forks    MN
# 518       55014   47801         Kettering    OH
# 519       54883   44269          Anderson    SC
# 520       54883   54778          Anderson    IN
# 521       53911   39940        Burlington    NC
# 522       53911   57041        Burlington    VT
# 523       54983   45181         Manhattan    KS
# 524       54889   44138       Port Arthur    TX
# 525       54006   40195         Kingsport    TN
# 526       54006   40195         Kingsport    VA
# 527       54232   39917       Rocky Mount    NC
# 528       53875   68277       Watsonville    CA
# 529       53797   53770            Elyria    OH
# 530       53488   40328      Harrisonburg    VA
# 531       52637   43471         Pensacola    FL
# 532       52508   50469           Olympia    WA
# 533       50600   50469             Lacey    WA
# 534       51210   45409     Coeur d'Alene    ID
# 535       52373   46354           Elkhart    IN
# 536       51829   49054          Kentwood    MI
# 537       51334   39861             Logan    UT
# 538       51334   39861             Logan    ID
# 539       51219   43859      Grand Island    NE
# 540       51491   50445         La Crosse    WI
# 541       51491   50445         La Crosse    MN
# 542       51105   39160      Battle Creek    MI
# 543       49019   39645    West Lafayette    IN
# 544       50604   40320            Joplin    MO
# 545       49810   47300         Mishawaka    IN
# 546       49810   47300         Mishawaka    MI
# 547       49713   39937        Twin Falls    ID
# 548       49723   43667              Enid    OK
# 549       48310   39521           Saginaw    MI

# %%
merged_df = pd.DataFrame(merged_df)
result_df = merged_df.drop_duplicates(subset=['City'])
result_df.reset_index()
result_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-93-14e67d70ad13> in <module>
#       1 merged_df = pd.DataFrame(merged_df)
# ----> 2 result_df = merged_df.drop_duplicates(subset=['City'])
#       3 result_df.reset_index()
#       4 result_df
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in drop_duplicates(self, subset, keep, inplace, ignore_index)
#    4809
#    4810         inplace = validate_bool_kwarg(inplace, "inplace")
# -> 4811         duplicated = self.duplicated(subset, keep=keep)
#    4812
#    4813         if inplace:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in duplicated(self, subset, keep)
#    4883         diff = Index(subset).difference(self.columns)
#    4884         if not diff.empty:
# -> 4885             raise KeyError(diff)
#    4886
#    4887         vals = (col.values for name, col in self.items() if name in subset)
#
# KeyError: Index(['City'], dtype='object')

# %%
result_df.loc[merged_df['City Name'] == 'Cincinnati']

# %%
result_df.to_csv("pop_income_city.csv", encoding="utf-8", index=False)

# %%
# only 2 cities have the exact same income
